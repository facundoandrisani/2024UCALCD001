# %% [markdown]
# <a href="https://colab.research.google.com/github/facundoandrisani/2024UCALCD001/blob/main/Exploracion_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **EJERCICIO DE PRUEBA FORMA PROPIA*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('NVDA.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2023-08-08  44.853001  45.242001  44.056000  44.664001  44.650639
# 1  2023-08-09  44.273998  44.312000  42.133999  42.554001  42.541264
# 2  2023-08-10  42.160000  43.574001  41.834999  42.388000  42.375317
# 3  2023-08-11  41.750999  42.018002  40.639000  40.855000  40.842777
# 4  2023-08-14  40.486000  43.799999  40.311001  43.752998  43.739902
#
#       Volume
# 0  353843000
# 1  586449000
# 2  492705000
# 3  533085000
# 4  690286000

# %%
df = df.drop(['Open','High','Low','Adj Close','Volume'], axis=1)
df.head()
# Out:
#          Date      Close
# 0  2023-08-08  44.664001
# 1  2023-08-09  42.554001
# 2  2023-08-10  42.388000
# 3  2023-08-11  40.855000
# 4  2023-08-14  43.752998

# %%
agosto2024 = df[df.Date.str.contains('2024-08')]
agosto2024['Close'].mean()
# Out:
# 104.17666633333333

# %% [markdown]
# **OTRA FORMA**

# %%
df.set_index('Date', inplace=True)

df_filtrado = df.loc['2024-08-01' : '2024-08-08']

# %% [markdown]
# **GRAFICO**

# %%
# Datos
x = np.agosto2024['Date']
y = np.agosto2024['Close']

# Gráfico de líneas
fig, ax = plt.subplots()
ax.plot(x, y, marker = "o", markersize = 5)
# ax.plot(x, y, marker = "o", ms = 5) # Equivalente
# plt.show()
